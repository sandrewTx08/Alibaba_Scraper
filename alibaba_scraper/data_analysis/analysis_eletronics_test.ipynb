# %%
import pandas as pd
from data_set import *

# %%
json_list = json_catalog('Eletronics', 20)

# %%
df = pd.read_json(json_list)

# %%
df.head(10)
# Out:
#               id                                              title  \
# 0  1600377143453  China Manufacturer Supply Professional Woodwor...
# 1  1600163176703  NaviHua Android10 Touch screen GPS navigation ...
# 2    62414025830  GOLF 10000 Mah Dual USB Type-c Power Bank Mobi...
# 3  1600369146138  Wholesale Vape Pen OEM e Cig Eletronic cigaret...
# 4  1600377189186  High Quality Dust Free Eletronic Saw Woodworki...
# 5  1600169017163  NAVIHUA Car DVD player GPS NaVIgation Auto Ste...
# 6  1600377101504  Professional High Accuracy Woodworking Machine...
# 7  1600171968193  NaviHua PX6 TESLA Model Android Car Headrest M...
# 8  1600098858908  Extrusion T Die Mold For PS/PC Eletronic Narro...
# 9  1600355251818  Top open safe operation hotel dishwasher eletr...
#
#                   price price_discount price_discount_percentage pieces_stock  \
# 0               $330.00       +$556.67                                  1 Set
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         159 non-null    int64
#  1   title                      159 non-null    object
#  2   price                      101 non-null    object
#  3   price_discount             159 non-null    object
#  4   price_discount_percentage  159 non-null    object
#  5   pieces_stock               159 non-null    object
#  6   review_title               159 non-null    object
#  7   review_count               159 non-null    object
#  8   link                       159 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 11.3+ KB
