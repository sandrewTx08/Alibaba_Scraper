# %%
import pandas as pd
from data_set import *

# %%
json_list = json_catalog('Eletronics', 20)

# %%
df = pd.read_json(json_list)

# %%
df
# Out:
#                 id                                              title  \
# 0    1600174798275  IC BQ40Z50RSMR-R1 Battery Charger Power Manage...
# 1    1600155383698  AHD1080P wide dynamic range bus truck side vie...
# 2      62238686751  Xiao mi Black Shark 2 Pro Original Octa Core 1...
# 3    1600261200009  XH-A128 TDA7498E BT 5.0 Digital Power Amplifie...
# 4      60678917373  3.0 inch 240*400 TFT LCD module full viewing a...
# ..             ...                                                ...
# 155    62510004584  Xiao mi Black Shark 3 Pro 12GB 256GB Octa Core...
# 156    60753682955  6AV2124-0MC01-0AX0 6AV2 124-0MC01-0AX0 HMI TP1200
# 157  1600252595982  Portable Multi-function 12000mah 12v General C...
# 158    60747121603  S71200 series PLC 6ES7 214-1BE30-0XB0 Digital ...
# 159  1600281796754  Mini Soldering Iron Adjustable Temperature Ele...
#
#                price price_discount price_discount_percentage pieces_stock  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         160 non-null    int64
#  1   title                      160 non-null    object
#  2   price                      103 non-null    object
#  3   price_discount             160 non-null    object
#  4   price_discount_percentage  160 non-null    object
#  5   pieces_stock               160 non-null    object
#  6   review_title               160 non-null    object
#  7   review_count               160 non-null    object
#  8   link                       160 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 11.4+ KB
